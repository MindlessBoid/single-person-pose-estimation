# %%
# !unzip ./drive/MyDrive/single-person-pose-estimation/dataset/tfrecords.zip
# Out:
# Archive:  ./drive/MyDrive/single-person-pose-estimation/dataset/tfrecords.zip
#    creating: dataset/tfrecords/
#    creating: dataset/tfrecords/valid/
#   inflating: dataset/tfrecords/valid/file_valid_03-208.tfrec
#   inflating: dataset/tfrecords/valid/file_valid_00-2048.tfrec
#   inflating: dataset/tfrecords/valid/file_valid_01-2048.tfrec
#   inflating: dataset/tfrecords/valid/file_valid_02-2048.tfrec
#    creating: dataset/tfrecords/train/
#   inflating: dataset/tfrecords/train/file_train_23-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_54-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_09-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_33-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_28-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_29-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_38-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_55-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_07-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_68-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_73-309.tfrec
#   inflating: dataset/tfrecords/train/file_train_35-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_58-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_41-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_18-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_32-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_70-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_43-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_52-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_59-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_14-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_27-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_39-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_24-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_17-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_10-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_53-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_04-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_37-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_19-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_06-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_49-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_45-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_48-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_72-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_71-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_01-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_03-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_57-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_16-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_56-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_40-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_30-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_65-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_47-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_63-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_42-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_12-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_22-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_15-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_46-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_34-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_60-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_13-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_51-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_36-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_69-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_25-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_02-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_44-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_50-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_67-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_26-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_11-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_61-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_21-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_31-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_05-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_08-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_20-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_62-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_64-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_00-2048.tfrec
#   inflating: dataset/tfrecords/train/file_train_66-2048.tfrec

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
### For reading
def parse_tfrecord_fn(example):
    feature_description = {
        "ann_id": tf.io.FixedLenFeature([], tf.int64),
        "image_id": tf.io.FixedLenFeature([], tf.int64),
        "image": tf.io.FixedLenFeature([], tf.string),
        "image_path": tf.io.FixedLenFeature([], tf.string),
        "width": tf.io.FixedLenFeature([], tf.int64),
        "height": tf.io.FixedLenFeature([], tf.int64),
        "keypoints/x": tf.io.VarLenFeature(tf.float32),
        "keypoints/y": tf.io.VarLenFeature(tf.float32),
        "keypoints/vis": tf.io.VarLenFeature(tf.int64),
        "keypoints/num": tf.io.FixedLenFeature([], tf.int64)
    }
    
    example = tf.io.parse_single_example(example, feature_description)
    example["image"] = tf.image.decode_image(example["image"], channels = 3, dtype = tf.float32, expand_animations =False)
    example["keypoints/x"] = tf.sparse.to_dense(example["keypoints/x"])
    example["keypoints/y"] = tf.sparse.to_dense(example["keypoints/y"])
    example["keypoints/vis"] = tf.sparse.to_dense(example["keypoints/vis"])
    return example
  ### example
def gen_examples_from_tfrecord(filepath, example_num):
  raw_dataset = tf.data.TFRecordDataset(filepath)
  parsed_dataset = raw_dataset.map(parse_tfrecord_fn)
  for example in parsed_dataset.take(example_num):
      for key in example.keys():
          if key != "image":
              print(f"{key}: {example[key]}")

      xcoords = example["keypoints/x"].numpy()
      ycoords = example["keypoints/y"].numpy()
      image = example["image"]
      h, w, c = image.shape
      print(f"Image shape: {image.shape}")
      plt.figure(figsize=(7, 7))
  
      plt.imshow(image)
      plt.scatter(xcoords  , ycoords  , marker = "o") # for heatmap size
      plt.show()

# %%
gen_examples_from_tfrecord('dataset/tfrecords/valid/file_valid_00-2048.tfrec', 50)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
