# %%
import tensorflow as tf

# %%
import sys
sys.path.append('/content/drive/MyDrive/single-person-pose-estimation')
from model import hourglass_blocks as hg

# %%
model = hg.create_hourglass_network((256, 256, 3), 17, 4, 256, hg.create_bottleneck, 'sigmoid')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  front_conv (Conv2D)            (None, 128, 128, 64  9472        ['input_1[0][0]']
#                                 )
#
#  front_bn (BatchNormalization)  (None, 128, 128, 64  256         ['front_conv[0][0]']
#                                 )
#
#  front_act (Activation)         (None, 128, 128, 64  0           ['front_bn[0][0]']
#                                 )
#
#  front_bottleneck1_skip_conv (C  (None, 128, 128, 12  8320       ['front_act[0][0]']
#  onv2D)                         8)
#
#  front_bottleneck1_convblock1_b  (None, 128, 128, 12  512        ['front_bottleneck1_skip_conv[0][
#  n (BatchNormalization)         8)                               0]']
#
# ...

# %%
tf.keras.utils.plot_model(model, show_shapes = True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !cp -r ./est ./drive/MyDrive/single-person-pose-estimation
