# %%
import tensorflow as tf

# %%
import sys
sys.path.append('/content/drive/MyDrive/single-person-pose-estimation')
from model import hourglass as hg
from configs import default_config as cfg

# %%
model = hg.create_hourglass_model(cfg.NUM_KEYPOINTS, 
                                 1,
                                 cfg.HG_NUM_CHANNELS,d
                                 cfg.IMAGE_SHAPE,
                                 cfg.HM_ACTIVATION)
# Out:
# Created Hourglass model:
#     1. 1 stacks.
#     2. 3659665 parameters. Call model.get_summary() for more detail.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  front_conv_1x1_1 (Conv2D)      (None, 128, 128, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['front_conv_1x1_1[0][0]']
#  alization)                     )
#
#  front_bottleneck_1_conv_1x1_1   (None, 128, 128, 64  4160       ['batch_normalization[0][0]']
#  (Conv2D)                       )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['front_bottleneck_1_conv_1x1_1[0
#  rmalization)                   )                                ][0]']
#
#  front_bottleneck_1_conv_3x3_2   (None, 128, 128, 64  36928      ['batch_normalization_1[0][0]']
#  (Conv2D)                       )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['front_bottleneck_1_conv_3x3_2[0
#  rmalization)                   )                                ][0]']
#
#  front_bottleneck_1_conv_1x1_3   (None, 128, 128, 12  8320       ['batch_normalization_2[0][0]']
#  (Conv2D)                       8)
#
#  front_bottleneck_1_skip (Conv2  (None, 128, 128, 12  8320       ['batch_normalization[0][0]']
#  D)                             8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['front_bottleneck_1_conv_1x1_3[0
#  rmalization)                   8)                               ][0]']
#
#  front_bottleneck_1_add (Add)   (None, 128, 128, 12  0           ['front_bottleneck_1_skip[0][0]',
#                                 8)                                'batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 128)  0           ['front_bottleneck_1_add[0][0]']
#
#  front_bottleneck_2_conv_1x1_1   (None, 64, 64, 64)  8256        ['max_pooling2d[0][0]']
#  (Conv2D)
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 64)  256         ['front_bottleneck_2_conv_1x1_1[0
#  rmalization)                                                    ][0]']
#
#  front_bottleneck_2_conv_3x3_2   (None, 64, 64, 64)  36928       ['batch_normalization_4[0][0]']
#  (Conv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 64)  256         ['front_bottleneck_2_conv_3x3_2[0
#  rmalization)                                                    ][0]']
#
#  front_bottleneck_2_conv_1x1_3   (None, 64, 64, 128)  8320       ['batch_normalization_5[0][0]']
#  (Conv2D)
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 128)  512        ['front_bottleneck_2_conv_1x1_3[0
#  rmalization)                                                    ][0]']
#
#  front_bottleneck_2_add (Add)   (None, 64, 64, 128)  0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  front_bottleneck_3_conv_1x1_1   (None, 64, 64, 128)  16512      ['front_bottleneck_2_add[0][0]']
#  (Conv2D)
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 128)  512        ['front_bottleneck_3_conv_1x1_1[0
#  rmalization)                                                    ][0]']
#
#  front_bottleneck_3_conv_3x3_2   (None, 64, 64, 128)  147584     ['batch_normalization_7[0][0]']
#  (Conv2D)
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['front_bottleneck_3_conv_3x3_2[0
#  rmalization)                                                    ][0]']
#
#  front_bottleneck_3_conv_1x1_3   (None, 64, 64, 256)  33024      ['batch_normalization_8[0][0]']
#  (Conv2D)
#
#  front_bottleneck_3_skip (Conv2  (None, 64, 64, 256)  33024      ['front_bottleneck_2_add[0][0]']
#  D)
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 256)  1024       ['front_bottleneck_3_conv_1x1_3[0
#  rmalization)                                                    ][0]']
#
#  front_bottleneck_3_add (Add)   (None, 64, 64, 256)  0           ['front_bottleneck_3_skip[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  hg0_downsample_f1_conv_1x1_1 (  (None, 64, 64, 128)  32896      ['front_bottleneck_3_add[0][0]']
#  Conv2D)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 128)  512        ['hg0_downsample_f1_conv_1x1_1[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f1_conv_3x3_2 (  (None, 64, 64, 128)  147584     ['batch_normalization_10[0][0]']
#  Conv2D)
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 128)  512        ['hg0_downsample_f1_conv_3x3_2[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f1_conv_1x1_3 (  (None, 64, 64, 256)  33024      ['batch_normalization_11[0][0]']
#  Conv2D)
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['hg0_downsample_f1_conv_1x1_3[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f1_add (Add)    (None, 64, 64, 256)  0           ['front_bottleneck_3_add[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0          ['hg0_downsample_f1_add[0][0]']
#
#  hg0_downsample_f2_conv_1x1_1 (  (None, 32, 32, 128)  32896      ['max_pooling2d_1[0][0]']
#  Conv2D)
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 128)  512        ['hg0_downsample_f2_conv_1x1_1[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f2_conv_3x3_2 (  (None, 32, 32, 128)  147584     ['batch_normalization_13[0][0]']
#  Conv2D)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 128)  512        ['hg0_downsample_f2_conv_3x3_2[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f2_conv_1x1_3 (  (None, 32, 32, 256)  33024      ['batch_normalization_14[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 256)  1024       ['hg0_downsample_f2_conv_1x1_3[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f2_add (Add)    (None, 32, 32, 256)  0           ['max_pooling2d_1[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['hg0_downsample_f2_add[0][0]']
#
#  hg0_downsample_f4_conv_1x1_1 (  (None, 16, 16, 128)  32896      ['max_pooling2d_2[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 128)  512        ['hg0_downsample_f4_conv_1x1_1[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f4_conv_3x3_2 (  (None, 16, 16, 128)  147584     ['batch_normalization_16[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 128)  512        ['hg0_downsample_f4_conv_3x3_2[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f4_conv_1x1_3 (  (None, 16, 16, 256)  33024      ['batch_normalization_17[0][0]']
#  Conv2D)
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['hg0_downsample_f4_conv_1x1_3[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f4_add (Add)    (None, 16, 16, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['hg0_downsample_f4_add[0][0]']
#
#  hg0_downsample_f8_conv_1x1_1 (  (None, 8, 8, 128)   32896       ['max_pooling2d_3[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_conv_1x1_1[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f8_conv_3x3_2 (  (None, 8, 8, 128)   147584      ['batch_normalization_19[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_conv_3x3_2[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f8_conv_1x1_3 (  (None, 8, 8, 256)   33024       ['batch_normalization_20[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 256)   1024        ['hg0_downsample_f8_conv_1x1_3[0]
#  ormalization)                                                   [0]']
#
#  hg0_downsample_f8_add (Add)    (None, 8, 8, 256)    0           ['max_pooling2d_3[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)   0           ['hg0_downsample_f8_add[0][0]']
#
#  hg0_downsample_f8_1_conv_1x1_1  (None, 4, 4, 128)   32896       ['max_pooling2d_4[0][0]']
#   (Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 4, 4, 128)   512         ['hg0_downsample_f8_1_conv_1x1_1[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_1_conv_3x3_2  (None, 4, 4, 128)   147584      ['batch_normalization_22[0][0]']
#   (Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 4, 4, 128)   512         ['hg0_downsample_f8_1_conv_3x3_2[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_1_conv_1x1_3  (None, 4, 4, 256)   33024       ['batch_normalization_23[0][0]']
#   (Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 4, 4, 256)   1024        ['hg0_downsample_f8_1_conv_1x1_3[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_1_add (Add)  (None, 4, 4, 256)    0           ['max_pooling2d_4[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  hg0_downsample_f8_2_conv_1x1_1  (None, 4, 4, 128)   32896       ['hg0_downsample_f8_1_add[0][0]']
#   (Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 4, 4, 128)   512         ['hg0_downsample_f8_2_conv_1x1_1[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_2_conv_3x3_2  (None, 4, 4, 128)   147584      ['batch_normalization_25[0][0]']
#   (Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 4, 4, 128)   512         ['hg0_downsample_f8_2_conv_3x3_2[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_2_conv_1x1_3  (None, 4, 4, 256)   33024       ['batch_normalization_26[0][0]']
#   (Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 4, 4, 256)   1024        ['hg0_downsample_f8_2_conv_1x1_3[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_2_add (Add)  (None, 4, 4, 256)    0           ['hg0_downsample_f8_1_add[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  hg0_downsample_f8_3_conv_1x1_1  (None, 4, 4, 128)   32896       ['hg0_downsample_f8_2_add[0][0]']
#   (Conv2D)
#
#  hg0_upsample_f8_short_conv_1x1  (None, 8, 8, 128)   32896       ['hg0_downsample_f8_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 4, 4, 128)   512         ['hg0_downsample_f8_3_conv_1x1_1[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 128)   512         ['hg0_upsample_f8_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg0_downsample_f8_3_conv_3x3_2  (None, 4, 4, 128)   147584      ['batch_normalization_28[0][0]']
#   (Conv2D)
#
#  hg0_upsample_f8_short_conv_3x3  (None, 8, 8, 128)   147584      ['batch_normalization_31[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 4, 4, 128)   512         ['hg0_downsample_f8_3_conv_3x3_2[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 128)   512         ['hg0_upsample_f8_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg0_downsample_f8_3_conv_1x1_3  (None, 4, 4, 256)   33024       ['batch_normalization_29[0][0]']
#   (Conv2D)
#
#  hg0_upsample_f8_short_conv_1x1  (None, 8, 8, 256)   33024       ['batch_normalization_32[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 256)   1024        ['hg0_downsample_f8_3_conv_1x1_3[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 256)   1024        ['hg0_upsample_f8_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg0_downsample_f8_3_add (Add)  (None, 4, 4, 256)    0           ['hg0_downsample_f8_2_add[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  hg0_upsample_f8_short_add (Add  (None, 8, 8, 256)   0           ['hg0_downsample_f8_add[0][0]',
#  )                                                                'batch_normalization_33[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 256)    0           ['hg0_downsample_f8_3_add[0][0]']
#
#  add (Add)                      (None, 8, 8, 256)    0           ['hg0_upsample_f8_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d[0][0]']
#
#  hg0_upsample_f8_merged_conv_1x  (None, 8, 8, 128)   32896       ['add[0][0]']
#  1_1 (Conv2D)
#
#  hg0_upsample_f4_short_conv_1x1  (None, 16, 16, 128)  32896      ['hg0_downsample_f4_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 128)   512         ['hg0_upsample_f8_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg0_upsample_f8_merged_conv_3x  (None, 8, 8, 128)   147584      ['batch_normalization_34[0][0]']
#  3_2 (Conv2D)
#
#  hg0_upsample_f4_short_conv_3x3  (None, 16, 16, 128)  147584     ['batch_normalization_37[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 128)   512         ['hg0_upsample_f8_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg0_upsample_f8_merged_conv_1x  (None, 8, 8, 256)   33024       ['batch_normalization_35[0][0]']
#  1_3 (Conv2D)
#
#  hg0_upsample_f4_short_conv_1x1  (None, 16, 16, 256)  33024      ['batch_normalization_38[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 256)   1024        ['hg0_upsample_f8_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 256)  1024       ['hg0_upsample_f4_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg0_upsample_f8_merged_add (Ad  (None, 8, 8, 256)   0           ['add[0][0]',
#  d)                                                               'batch_normalization_36[0][0]']
#
#  hg0_upsample_f4_short_add (Add  (None, 16, 16, 256)  0          ['hg0_downsample_f4_add[0][0]',
#  )                                                                'batch_normalization_39[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0          ['hg0_upsample_f8_merged_add[0][0
#                                                                  ]']
#
#  add_1 (Add)                    (None, 16, 16, 256)  0           ['hg0_upsample_f4_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_1[0][0]']
#
#  hg0_upsample_f4_merged_conv_1x  (None, 16, 16, 128)  32896      ['add_1[0][0]']
#  1_1 (Conv2D)
#
#  hg0_upsample_f2_short_conv_1x1  (None, 32, 32, 128)  32896      ['hg0_downsample_f2_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg0_upsample_f4_merged_conv_3x  (None, 16, 16, 128)  147584     ['batch_normalization_40[0][0]']
#  3_2 (Conv2D)
#
#  hg0_upsample_f2_short_conv_3x3  (None, 32, 32, 128)  147584     ['batch_normalization_43[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg0_upsample_f4_merged_conv_1x  (None, 16, 16, 256)  33024      ['batch_normalization_41[0][0]']
#  1_3 (Conv2D)
#
#  hg0_upsample_f2_short_conv_1x1  (None, 32, 32, 256)  33024      ['batch_normalization_44[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 256)  1024       ['hg0_upsample_f4_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 256)  1024       ['hg0_upsample_f2_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg0_upsample_f4_merged_add (Ad  (None, 16, 16, 256)  0          ['add_1[0][0]',
#  d)                                                               'batch_normalization_42[0][0]']
#
#  hg0_upsample_f2_short_add (Add  (None, 32, 32, 256)  0          ['hg0_downsample_f2_add[0][0]',
#  )                                                                'batch_normalization_45[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0          ['hg0_upsample_f4_merged_add[0][0
#                                                                  ]']
#
#  add_2 (Add)                    (None, 32, 32, 256)  0           ['hg0_upsample_f2_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_2[0][0]']
#
#  hg0_upsample_f2_merged_conv_1x  (None, 32, 32, 128)  32896      ['add_2[0][0]']
#  1_1 (Conv2D)
#
#  hg0_upsample_f1_short_conv_1x1  (None, 64, 64, 128)  32896      ['hg0_downsample_f1_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg0_upsample_f2_merged_conv_3x  (None, 32, 32, 128)  147584     ['batch_normalization_46[0][0]']
#  3_2 (Conv2D)
#
#  hg0_upsample_f1_short_conv_3x3  (None, 64, 64, 128)  147584     ['batch_normalization_49[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg0_upsample_f2_merged_conv_1x  (None, 32, 32, 256)  33024      ['batch_normalization_47[0][0]']
#  1_3 (Conv2D)
#
#  hg0_upsample_f1_short_conv_1x1  (None, 64, 64, 256)  33024      ['batch_normalization_50[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 256)  1024       ['hg0_upsample_f2_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 256)  1024       ['hg0_upsample_f1_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg0_upsample_f2_merged_add (Ad  (None, 32, 32, 256)  0          ['add_2[0][0]',
#  d)                                                               'batch_normalization_48[0][0]']
#
#  hg0_upsample_f1_short_add (Add  (None, 64, 64, 256)  0          ['hg0_downsample_f1_add[0][0]',
#  )                                                                'batch_normalization_51[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0          ['hg0_upsample_f2_merged_add[0][0
#                                                                  ]']
#
#  add_3 (Add)                    (None, 64, 64, 256)  0           ['hg0_upsample_f1_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_3[0][0]']
#
#  hg0_upsample_f1_merged_conv_1x  (None, 64, 64, 128)  32896      ['add_3[0][0]']
#  1_1 (Conv2D)
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  hg0_upsample_f1_merged_conv_3x  (None, 64, 64, 128)  147584     ['batch_normalization_52[0][0]']
#  3_2 (Conv2D)
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  hg0_upsample_f1_merged_conv_1x  (None, 64, 64, 256)  33024      ['batch_normalization_53[0][0]']
#  1_3 (Conv2D)
#
#  batch_normalization_54 (BatchN  (None, 64, 64, 256)  1024       ['hg0_upsample_f1_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  hg0_upsample_f1_merged_add (Ad  (None, 64, 64, 256)  0          ['add_3[0][0]',
#  d)                                                               'batch_normalization_54[0][0]']
#
#  hg0_conv_1x1_1 (Conv2D)        (None, 64, 64, 256)  65792       ['hg0_upsample_f1_merged_add[0][0
#                                                                  ]']
#
#  batch_normalization_55 (BatchN  (None, 64, 64, 256)  1024       ['hg0_conv_1x1_1[0][0]']
#  ormalization)
#
#  hg0_conv_1x1_predict (Conv2D)  (None, 64, 64, 17)   4369        ['batch_normalization_55[0][0]']
#
# ==================================================================================================
# Total params: 3,659,665
# Trainable params: 3,641,617
# Non-trainable params: 18,048
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
