# %%
import torch
import tensorflow as tf

# %% [markdown]
# ---
#
#
#
# ---
# **Person Dectector YOLOv5**

# %%
yolov5 = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom

# %% [markdown]
# ---
#
#
#
# ---
# **Keypoints Dectector: Stacked Hourglass Network**

# %%
HGs4 = tf.keras.models.load_model('/content/drive/MyDrive/single-person-pose-estimation/trained_models/S4_E120_Adam_IOU')
HGs2 = tf.keras.models.load_model('/content/drive/MyDrive/single-person-pose-estimation/trained_models/S2_E30_Adam_IOU')

# %% [markdown]
# ---
#
#
#
# ---
# **DEMO**

# %%
import sys
sys.path.append('/content/drive/MyDrive/single-person-pose-estimation')
# %matplotlib inline
from configs import default_config as cfg
from demo import *
from utilities.data_utils import read_cv_image
from utilities.javascript_utils import take_photo, start_video_stream

# %%
demo1 = Demo(yolov5, HGs4, cfg, max_num_ppl = -1, person_conf_thres=0.1, keypoints_conf_thres=0.5) # max_num_ppl = -1 to show full

# %% [markdown]
# ---
# Image

# %%
image = read_cv_image('/content/drive/MyDrive/single-person-pose-estimation/demo_images/yoga.jpg', show=True)

# %%
demo1.detect(image)

# %%
demo1.show(show_bboxes=True)

# %%
demo1.show_separate()

# %% [markdown]
# ---
#
# Webcam image

# %%
demo2 = Demo(yolov5, HGs2, cfg, person_conf_thres=0.5, keypoints_conf_thres=0.5) # max_num_ppl = -1 to show full

# %%
take_photo(demo2)

# %% [markdown]
# ---
#
# Webcam video

# %%
start_video_stream(demo2)
